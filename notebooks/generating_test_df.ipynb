# %%
from salicml.data import data
import pandas as pd

# %%
data.planilha_orcamentaria.idSegmento.unique()
# Out:
# array(['53', '85', '71', '5E', '52', '56', '81', '61', '2J', '5F', '31',
#        '88', '69', '51', '5A', '33', '6E', '34', '87', '77', '32', '29',
#        '41', '11', '25', '14', '26', '55', '46', '28', '27', '68', '54',
#        '12', '74', '59', '4B', '65', '13', '42', '72', '2C', '6D', '62',
#        '5I', '57', '83', '73', '58', '23', '4F', '43', '66', '84', '86',
#        '44', '15', '67', '82', '6F', '24', '6C', '64', '2P', '5B', '49',
#        '2L', '2O', '6B', '5Q', '2K', '6A', '21', '5P', '17', '2B', '4G',
#        '48', '5N', '5K', '5G', '5O', '5C', '5H', '5J', '4C', '4A', '4E',
#        '6G', '2A', '5R', '36', '6H', '4D', '2G', '2E', '2D', '2F', '5L',
#        '9O', '5X', '4H', '1D', '6T', '2R', '1B', '37', '2S', '6M', '18',
#        '1I', '2T', '5W', '9I', '6I', '9C', '6J', '1A', '1H', '9J', '9P',
#        '5T', '38', '5U', '6S', '5S', '5Z'], dtype=object)

# %% [raw]
# data.planilha_orcamentaria.idSegmento.unique()

# %%
is_seg = data.planilha_orcamentaria['idSegmento']=='53'

# %%
df = pd.DataFrame()
for seg in data.planilha_orcamentaria.idSegmento.unique():
    is_seg = data.planilha_orcamentaria['idSegmento'] == seg
    df = pd.concat([df,data.planilha_orcamentaria[is_seg].head(20)], ignore_index=True)

# %%
df.idSegmento.unique()
# Out:
# array(['53', '85', '71', '5E', '52', '56', '81', '61', '2J', '5F', '31',
#        '88', '69', '51', '5A', '33', '6E', '34', '87', '77', '32', '29',
#        '41', '11', '25', '14', '26', '55', '46', '28', '27', '68', '54',
#        '12', '74', '59', '4B', '65', '13', '42', '72', '2C', '6D', '62',
#        '5I', '57', '83', '73', '58', '23', '4F', '43', '66', '84', '86',
#        '44', '15', '67', '82', '6F', '24', '6C', '64', '2P', '5B', '49',
#        '2L', '2O', '6B', '5Q', '2K', '6A', '21', '5P', '17', '2B', '4G',
#        '48', '5N', '5K', '5G', '5O', '5C', '5H', '5J', '4C', '4A', '4E',
#        '6G', '2A', '5R', '36', '6H', '4D', '2G', '2E', '2D', '2F', '5L',
#        '9O', '5X', '4H', '1D', '6T', '2R', '1B', '37', '2S', '6M', '18',
#        '1I', '2T', '5W', '9I', '6I', '9C', '6J', '1A', '1H', '9J', '9P',
#        '5T', '38', '5U', '6S', '5S', '5Z'], dtype=object)

# %%
data.planilha_comprovacao.idSegmento.unique()
# Out:
# array(['33', '11', '2J', '68', '5G', '4B', '32', '12', '2L', '31', '13',
#        '5K', '9I', '6C', '5F', '62', '65', '5I', '5E', '1I', '17', '26',
#        '5A', '6E', '23', '6D', '6B', '61', '1A', '44', '4F', '5B', '41',
#        '2T', '82', '14', '6H', '2C', '6F', '28', '81', '6A', '1B', '5N',
#        '49', '46', '42', '37', '5W', '71', '2F', '54', '5R', '5P', '2P',
#        '2O', '2A', '2K', '4G', '1D', '55', '21', '6G', '84', '5L', '85',
#        '59', '5J', '2B'], dtype=object)

# %%
df2 = pd.DataFrame()
for seg in data.planilha_comprovacao.idSegmento.unique():
    is_seg = data.planilha_comprovacao['idSegmento'] == seg
    df2 = pd.concat([df2,data.planilha_comprovacao[is_seg].head(20)], ignore_index=True)

# %%
df2
# Out:
#       IdPRONAC  PRONAC             DataProjeto  idPlanilhaAprovacao  \
# 0       209702  171436 2017-05-16 21:55:49.903              2407740
# 1       209702  171436 2017-05-16 21:55:49.903              2407730
# 2       203598  161920 2016-06-03 11:47:49.503              2115445
# 3       203598  161920 2016-06-03 11:47:49.503              2115446
# 4       203598  161920 2016-06-03 11:47:49.503              2115443
# 5       203598  161920 2016-06-03 11:47:49.503              2115442
# 6       203598  161920 2016-06-03 11:47:49.503              2115459
# 7       203598  161920 2016-06-03 11:47:49.503              2115449
# 8       203598  161920 2016-06-03 11:47:49.503              2115451
# 9       183801  148854 2014-08-19 13:16:30.940              1312215
# 10      190393  150705 2015-02-03 17:32:53.667              1514201
# 11      190393  150705 2015-02-03 17:32:53.667              1514212
# 12      209702  171436 2017-05-16 21:55:49.903              2396312
# ...

# %%
data.planilha_captacao
# Out:
#         Idcaptacao   Pronac Segmento NumeroRecibo    CgcCpfMecena TipoApoio  \
# 0                1  0710601       61        00008  05911608000191         1
# 1                2  0710601       61        00009  07483926000124         1
# 2                3  0710601       61        00010  03084709000100         1
# 3                4  0710601       61        00011  55444095000124         1
# 4                5  0710601       61        00012  09794389000169         1
# 5                6  0710601       61        00013  74386137000162         1
# 6                7  0710601       61        00014  35882562000190         1
# 7                8  0710601       61        00015  51855716000101         1
# 8                9  0710601       61        00016  59970624000184         1
# 9               10  0710601       61        00017  01024914000155         1
# 10              11  0710601       61        00018  03098482000152         1
# ...

# %%
len(data.planilha_captacao.Pronac.unique()[:5000])
# Out:
# 5000

# %%
df3 = pd.DataFrame()
for p in data.planilha_captacao.Pronac.unique()[:2000]:
    is_p = data.planilha_captacao['Pronac'] == p
    df3 = pd.concat([df3, data.planilha_captacao[is_p].head(10)], ignore_index=True)

# %%
df3
# Out:
#       Idcaptacao   Pronac Segmento NumeroRecibo    CgcCpfMecena TipoApoio  \
# 0              1  0710601       61        00008  05911608000191         1
# 1              2  0710601       61        00009  07483926000124         1
# 2              3  0710601       61        00010  03084709000100         1
# 3              4  0710601       61        00011  55444095000124         1
# 4              5  0710601       61        00012  09794389000169         1
# 5              6  0710601       61        00013  74386137000162         1
# 6              7  0710601       61        00014  35882562000190         1
# 7              8  0710601       61        00015  51855716000101         1
# 8              9  0710601       61        00016  59970624000184         1
# 9             10  0710601       61        00017  01024914000155         1
# 10            59  0710789       13        00001  33000167000101         2
# 11            60  0710789       13        00002  33000167000101         2
# ...

# %%
data.planilha_aprovacao_comprovacao
# Out:
#         IdPRONAC  PRONAC             DataProjeto  idPlanilhaAprovacao  \
# 0         206555  163776 2016-10-06 18:14:06.297              1994185
# 1         206555  163776 2016-10-06 18:14:06.297              1994185
# 2         206555  163776 2016-10-06 18:14:06.297              1994185
# 3         206555  163776 2016-10-06 18:14:06.297              1994185
# 4         206555  163776 2016-10-06 18:14:06.297              1994185
# 5         206555  163776 2016-10-06 18:14:06.297              1994185
# 6         206555  163776 2016-10-06 18:14:06.297              1994185
# 7         206555  163776 2016-10-06 18:14:06.297              1994185
# 8         206555  163776 2016-10-06 18:14:06.297              1994185
# 9         206555  163776 2016-10-06 18:14:06.297              1994185
# 10        206555  163776 2016-10-06 18:14:06.297              1994185
# 11        206555  163776 2016-10-06 18:14:06.297              1994185
# ...

# %%
df4 = pd.DataFrame()
for p in data.planilha_aprovacao_comprovacao.PRONAC.unique()[:2000]:
    is_p = data.planilha_aprovacao_comprovacao['PRONAC'] == p
    df4 = pd.concat([df4, data.planilha_aprovacao_comprovacao[is_p].head(20)], ignore_index=True)

# %%
df4
# Out:
#        IdPRONAC   PRONAC             DataProjeto  idPlanilhaAprovacao  \
# 0        206555   163776 2016-10-06 18:14:06.297              1994185
# 1        206555   163776 2016-10-06 18:14:06.297              1994185
# 2        206555   163776 2016-10-06 18:14:06.297              1994185
# 3        206555   163776 2016-10-06 18:14:06.297              1994185
# 4        206555   163776 2016-10-06 18:14:06.297              1994185
# 5        206555   163776 2016-10-06 18:14:06.297              1994185
# 6        206555   163776 2016-10-06 18:14:06.297              1994185
# 7        206555   163776 2016-10-06 18:14:06.297              1994185
# 8        206555   163776 2016-10-06 18:14:06.297              1994185
# 9        206555   163776 2016-10-06 18:14:06.297              1994185
# 10       186116  1411084 2014-10-16 10:04:46.123              1381600
# 11       186116  1411084 2014-10-16 10:04:46.123              1381600
# ...

# %%
data.planilha_projetos
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/repos/salic-ml/src/salicml/data/loader.py in __getattr__(self, attr)
#      30         try:
# ---> 31             return self._cache[attr]
#      32         except KeyError:
#
# KeyError: 'planilha_projetos'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/.virtualenvs/salic/lib/python3.7/site-packages/pandas-0.24.2-py3.7-linux-x86_64.egg/pandas/io/pickle.py in try_read(path, encoding)
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#
# ~/.virtualenvs/salic/lib/python3.7/site-packages/pandas-0.24.2-py3.7-linux-x86_64.egg/pandas/io/pickle.py in read_wrapper(func)
# ...
