# %% [markdown]
# # Viabilidade técnica de extração de informação dos Comprovantes PDF

# %% [markdown]
# ## Hipótese

# %% [markdown]
# A principal hipose é que *Podemos Extrair* o custo e o CFP/CNPJ a partir dos comprovantes submetidos pelos proponentes.
#
# O *Resultado Esperado* é que, para cada comprovante submetido, conseguimos extrair o CNPJ/CPF do fornecedor, além do custo empenhado pela nota fiscal
#
# *Teremos sucesso quando* conseguirmos extrair tais informações de pelo menos 50% dos comprovantes.

# %% [markdown]
# ## Solução Proposta

# %% [markdown]
# A solução proposta usa a OCR Tesseract (https://github.com/tesseract-ocr) para a extração de texto a partir de imagens. Para isso a seguinte sequencia de processamento foi necessário:
# * [ x ] Querbrar os pdf para ter um comprovante por pdf
# * [x] Converter os arquivos pdf em arquivos de imagem
# * [x] Fazer o mínimo de processamento de imagem para melhorar a qualidade dos comprovantes
# * [x] Extrair o texto a partir da imagem, utilizando o Tesseract
# * [x] Extrair por meio de regex o CNPJ/CPF presente no arquivo texto extraído
# * [ ] Extrair por meio de regex o valor empenhado na nota fiscal

# %% [markdown]
# ### 1. Converter pdf em arquivo texto

# %%
import argparse
import cv2
import pytesseract
import os
import glob
from PIL import Image, ImageEnhance, ImageFilter

foldernames = sorted(glob.glob('./*/'))
len(foldernames)
for f in foldernames:
    foldersearch= f + "*.jpg"
    filenames = sorted(glob.glob(foldersearch)) 
    i = 0
    for file in filenames:
        print(file)
        im = Image.open(file)
        im = im.filter(ImageFilter.MedianFilter())
        enhancer = ImageEnhance.Contrast(im)
        im = enhancer.enhance(2)
        im = im.convert('1')
        im.save(file)
        text = pytesseract.image_to_string(Image.open(file), lang='por')
        
        os.remove(file)
        print(text)
        text_file = open( f+"%s.txt" % i , "w")
        i += 1
        text_file.write(text)
        text_file.close()
# Out:
# ./1613119/document-page0.jpg
# LATAM
#
# AIRLINES
#
# TAM Linhas Aéreas S/A
#
# "%
#
# Rua Verbo Divino Nº 2001, andares: 3º conj. 31 e 32,4º conj. 41 e 42, 5"cong. 51 e 52, 6º conj. 61 e 62, 8º conj. B1 e £2,
# 10º conj. 101 e 102, 12º conj. 121 e 122,13º conj. 131 e 132,15º conj. 151,16º conj. 161, 17*º cong. 171 e 172,
#
# Edifício Condomínio Espaço Empresarial Nações Unidas. Chácara Santo Antonio, CEP 047 19-002, São Paulo / SP
#
# CNPJ (M.F.) Nº D2.012.662/0D001-60 - INSCR. Est. Nº 112.347.127.116
#
# Informação sobre sua passagem
#
# Este é o seu comprovante de compra e contém os detalhes do serviço adquirido.
#
# Nodtadasuamgem não é necessario leva-lo com você.
# Tenha em mãos apenas o código de reserva e a documentação de embarque.
#
# ILANA BAR NISSIM WIRGUES
#
# KCUGKO
# Adulto
#
#
#
# Descrição do pagamento
#
#
#
# Tarlfa equivalente em moeda de BRO ds I0000DCCCOOLIN2O 601667
# W '
# Taxas etou impoetos (2) BRL S5,84 () BRL: Reais
#
# a Detalhe ttas taus etou tmpostos, Passagent
# Totai passagem 3S71-2T170ASSASA BRL 6S3,64 BRL BR 55,54 (Taxa de embarque vôo domestico)
# Total pago BRL 683,64
# Itinerário
#
#
#
# LA 3251
# por SÃO PAULO FOZ DO IGUAÇU sEG sEG 1 peça de 23
# Arines — CONGONHAS CATARATAS me EP quue 15 Eoom-G GOXDNS 5A Kg
# Brasã
#
# aa sÃo
#
# ' por — FOZDOIGUAÇU PALLO sEx sEX 1 peça de 23
#
# aam Abines —— CATARATAS CONGONHAS — gragucis 199  aguunas 19M  Economy- G CORONS — 8D Kg
#
# Brasd
#
# e Ifornmação Importante: Se voCÊ ou algum de 5eus acompanhantes INer alguma necessidade especial, INformne-nos quando Tor Tazer a Sua reserva em até 48 horas
# antes do seu voo, ligando para o Contact Center peto 4002-57D0 (capitais) e 0300 57D 5700 (todo o Bras).
# - IMformação Importante: Lembre-se que 06 voc6 dentro do 8rasi, com origem ou destino em São Paulo, podem operar no aeroporto de Guaruíhos (GRU), Conqonhas
#
# CGH) ou VEacopos (VCP).
# .MmmmmMmmmmmemmmwmammmmmm
# Suficierte para pegar sua bagagem despacthada e levá-la com você e defina como será feito o trajeto entre o6 aeroportos (tand, Onibus, eic).
#
# Detalhe companhias aéreas
#
#
#
# LATAM Alrfines Brasil LATAM Alrtines Brasil
#
# LA 3251
# LA 3250 LATAM Alrines Brasã LATAM Alriines Bracil
#
# Informação local
#
# 13
# ./1613119/document-page1.jpg
# AIRLINES
#
# TAM Linhas Aéreas SA
#
# conj. 81 e 62, 8º conj. B1 e &2,
# w conf. 181, 17º conj. 171 e 172,
#
#
#
#
#
#
#
#
#
#
#
#
# Informação sobre sua passagem
#
# Este é o seu comprovante de compra e contém os detalhes do serviço adquirido.
# Nadladasuamgem não é necessario levalo com você.
# Tenha em mãos apenas o código de reserva e a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# n
# A '.*m jm r,*,b—— o
#
#
#
#
#
# d T AN
# e
# Pa uwrê.;a“(.w«.g%g,w,m»,v.,«;ui::
#
# A
#
#
#
# e ªwmr. ú
#
# nxm., Ç o
#
#
#
# EE n
# n
# Í *«;“' UAA
#
#
#
#
#
# _;:,:a»-«w i
#
#
#
#
#
#
#
#
#
#
#
# W. MEN »ww
#
#
#
#
#
# AA
#
#
#
#
#
# ;;:':';:w.av;,wr—««;;,«:v o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# *Ez*:zªªitªm'r-«j«r;gx;w:“;“ M NA 4«', E N ,A,,«:yg«'u " NE
# ú A .J. W **., oA MEN A E A AA G u0 " R
# Â U “""rªª'«ê:«&?íí«?vª:ªwªr'êª A '*"::ã..«»...,.,..:*“ 4 J l A o A ..,r_,a':*“ ';“W'Et',m.n...x, "
# r.«;,»,.»g.».';«',![“!ãô"«' ,.;;5,:,:*»' v.«,,_, o ú : : “AM 1 ', S em E
# AAA G A «um.;,»x.,u(_l:ª,'-àw ú !,.,«:.«n.xw'“:;w a é R AN
# “3 M a aa E R A NA Â A
#
#
#
#
#
#
#
#
#
# ( U
# s
# A .,Jm,..».:;'u«».ªã—*'ªl,',i*)m"—.—!'
# *' xw E o Rã A a X,),._çwé.,.m,w.
# " n:;;-««,-_:m—., me M || e N E NAA RNA
# e A s »,;»:« N ET NTNAA
#
# mammmmmm
#
# N W 'u
# d r.,âizr,x!*»z:::iê:,,« u o d
#
# | o WM o |
# AA w'*—“'*"ª“ 1 1l ) a p t 1 L ” .—A*“%*r'*“#'« ' Í':':'f':'«:'f:«':v ªm.»,ii'«z,;':::a;w
# .umu»i:»;u-:',;.5&12,_0 ú «Wm,_«z,..'r,.m . <n du NAA ) o S ERENVRTIDO DNA eÇÃS MEmA RA TE i dn A .
#
# x*,Zy,*(;r.« -íx..,""'““'ª““'Y'ª'ª 3,;1,.,;31..,.,:9.,.(,»,,]:0, ,'. e D d :w'»_'& x A i 1 m lt m “ u v,,,,x,,.gê:.,àgg%:,' E U W,:,, “
#
# E A A P i é d ú ú e S L M M
# d .r,.,..»,x.__.:...v,.,y,.í.,,â» A U a A A A n AA
# M tW..,,4.,3,(.;,3».,;».),4;—;,7,:,;&,“;;.,« N o U m | U 1 A
#
# Ú : o É h | j n
# úl d AN v i ,v o o d aa NAA o u ú L AA AA AAA S in aa A
#
# U AA
# A A
#
#
#
#
#
# » Ifomação Importante: Se você ou algum de seus fver allguma necessidade especial, Informe-nos quando for fazer a Sua reserva em até 48 horas.
# mmmmmmowmmdmm[mm]emmmmum
# « Iformação Importante: Lembre-se que 05 voCê dentro do Bras$, com ceigem ou destino em São Paulo, podem operar no aeroporto de Guanuíhos (GRU), Congonhas
# CEH) nue Viracopos (VCF).
#
# .MMWMWMMM Dporto vDcê gera responsaável pelo transporte entre eles. Confime a distância, garanta que você terá tempo
# Ssuficerte para pegar sua bagagem despaectiada e | mme%m%mnwmmmmmm
#
#
#
#
#
# Detalhe companhias aéreas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,;;.«»,;Ígj,,,ym,;_,[,.-..,_5::5»»« b ú ;.»m«,,»m 1l
#
#
#
#
#
#
#
# Informação local
#
# 13
# ./1613119/document-page2.jpg
# |
# |
#
#
#
# '
# É
# 4
# É
# |
#
#
#
#
#
#
#
#
#
#
#
#
#
# :
#
#
#
#
#
#
#
# É
# :
#
#
#
# |
# :
#
#
#
# :
#
# :
# É
# é
#
#
#
# É
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AIR
#
# TAM Linhas Aéreas S/A
#
# Rua Verbo Divino Nº 2001, andares: 3º conj. 31 e 32,4º conf. 41 e 42, 5"conf. 51 e 52, 6º coni. 01 e 62, 8º conj. B1 e &2,
# 1Dº conj. 101 e 102, 12º conj. 121 e 122, 13º mm. 131 e 132, 15º conf, 151, 16º coni. 161, 17º cons. 171 e 172,
#
# Edificio Condominio Espaço Empresarial Nações Unidas. Chaácara Santo Antonio, CEP 04719-002, São Paulo / SP
#
# GNPJ IM.F.]) Nº D2012.B62/D0O01-80 - INSTR. Est. Nº 112 347.127.116
#
#
#
#
#
#
#
#
#
# Informação sobre sua passagem
#
# Este é o seu comprovante de compra e contém os detalhes do serviço adqu
#
# No dia da sua viagem, não é necessario leva-do com você.
# Tenha em mãos apenas o coódigo de reserva e a documentação de embarque.
#
#
#
# ido.
#
# 'xír'f'('r'-ª)':íaíªª?:"'ªíª"ª'"ª“ª-ªªfívl!*"“w e o
#
# TA
#
# e N
#
# [m
# À i mu N A
# | SNc l
#
# R A A MN 'r"-*u a ,.«:.«,r.«,»n.«»,;,»:,-_ SNA
# E a «aa««v:«;:º;.x.!.x_..*._«aí.ç,.m,,s A «x«zuse.!,.,,_g.y,..[ N “'!mr- M
#
#
#
#
#
#
#
# wz:w:r;«a:a:._
#
# V A A rxr«“»:w,ãmz!“%s&!'»ª«%ªªªã:—'—:ãíêr.“““* :::::*,s:::a*v"ª ú
#
#
#
# ú
#
#
#
# a
#
# m
#
#
#
# maa -. f
#
# S mm..
# E
#
# A ú S «lºxx»º.»,—-n u w.«,u'r-;n,. ,.v.,.
# - a A R ,““,._,,,3,
#
#
#
#
#
# ANT ún ªxº-'ªííàã«:ª“*
#
# e
#
#
#
# ,1
# 2
# ê
# &
# &
# ÉD
#
# ÉÉ
# õ
# 1S
# [)
# =
# 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# N ET o
# ú N *,er.qÁ,w;;r.n;;;;;jjmy)y'.v:«;r,w».[. ul " d
# ,.,.,.,_r, A ' |
#
# ÇÇ.
# e
#
# SNE AN
# n ;v,n(n._».,,. e
#
# .,.-gx»". u
#
#
#
#
#
#
#
#
#
#
#
#
#
# U “")í'*N"“ª ó
#
# d
# 1%:.13 T ,,».r«“'“:r.vw .»
#
#
#
# 1
#
# A D
# u
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
# S(;'z!.:;w,,.y o AENA " A a d e PTA *
# á »«:;':.:«ªww.'.,.»,s,_.».m.z«» |EA ,»'»s;a««»:.,.«x—w':*' e n to L é S ú N É o & o Ãrw«;y;, fw“wiê,«i_«v.r,,.,.wr.;,(,533;(:..,
# R R RA a a ebeae- W
# AN A MTA é . l A A
# ,_nw.,,»..,»-.lª! '—».« o o a AA ,"w | RRA 299 RETA Ú
# Tanfa : A a aA M N ( aa 1 f a
# . BRL s47,90
# TRCLASTINTIO
#
#
#
# =
# =
# &
# &.
# =
# Õ
#
# '--'-""'"";'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í'.í':"'-"-"-' -'“'r E o l a o
# T S
#
# TSAA
# o
#
# PNENA MA AAAA AAAA SNSNA OEOSEÇ— Ç— p
# A ;_W.,.x.-«».w.,,(,;;g i f «am h ».«,-.r,vas.»,,v.z',:vys_z,;»r«;::»».a;.w,:'_.»v,,w,».u,s,mmwu.«,.»vw..,.»,«_g;.»,w»,x,)'_:»',.t:gv.,sy»»«.v,r,wg..Ww,.;.y.,.mW,,,.m,.,,.y,.,m_»,,,wm e o U
# .xzr.syy A o o u:l:v'«,.h.,«vvvq,.'ZM“K(r;*;*,ív::*hr,v,, J o o :*«-“'nyt»—:vv_::.,;;m_v,“_W;g_,:r' ú .«vr'«'_::.
# N | | b o N e
# A é a SA AN
# A a d
# S e N s Y WEA E RA w.w-r.
#
# E a dA e ú A 1 » í A MST
# d A A S A é : rr-;.«:ª' d
#
# E aene a A
# u o j | |
#
# d
#
# ,_._z;..—,—s:..,.»,az;«,;,.m,
#
# A ú ) M
# AAA e
# Â º'ªw.:;:.::u» ' Â N :ª'” ÂN
#
# , ú
# A T N ú ó ú : 1 o A o
# .,.«x “mrmr'.'f.ªaw'-vt»'“ Um S S R A td : «nvxf-'rª:íx'npw L E N A f u LS v«o. & d E 1 MA «v.««!, qv.mm A
#
# ú E d a e " u U
# .y,.,.,,y,«(,,,Q,«,;«;,,,.:W,xm.«,',,,ô e o MM A E e Un
#
# 1 ENENA .m.«vçj.,,.,.,.,x..v. d
# u iA a AN :.»:»««*«wn««º'«,»,»«º'vr» ª""“'“"r..',""*"' o
#
# « Ifomação Importante: Se você ou algum de seus acompanhantes fver alguma necessidade especial, Informe-nos quando for fazer a Sua resernve em até 48 horas
# antes do seu voo, lkgando para o Conftact Center peto 40025770 (capítals) e 0300 570 5700 (iodo o Brasl).
# « INformação Importante: Lembre-se que 065 vocês deniro do Brasll, com origem ou destino em São Paulo, podem operar no aeroporto de Guaruíhos (GRU), Congonhas
# CGH) /ou Viracopos: (VCP])
# .MmmmmMmmmmmemmwmma garanta que você terá tempo
# Sufcierte para pegar sua bagagem despachada e levi-a com você e defina como será feito o irajeto entre 05 aemportos (to0, ónfhus, elic).
#
#
#
#
#
# Detalhe companhias aéreas
#
# f um.w«º'-“x:rsx'«'«'»'rª«r« M o " Úó NA a M g%f.;ãf:!'âa:'—!'ª.i!?,(g.[ª"*';.â,:::!;:;ª“à'ª'.':ª."'![——'r-«iv' t o ;“wn Y AA AAA
# , A A A AA a A
# d A W;W“;:líiy ú
#
# e NTS
# e
#
# | d .—,.,.«;»..-..,.« d EN :
# A d " A A S d
#
# VM E º PUPA A A A e d d o MA a
# UN V A A ANA RLA o R :,—;.»A L ú d E : NA
#
#
#
#
#
# 13
# ./1613119/document-page3.jpg
# R
#
# Al
#
#
#
# e 82,
#
# . 81
# . 71 e172,
#
# conj,
#
# 81 e 62, &º
# 161, 17º
#
# conj.
#
# . 51 e 62, &*
#
# FT 19-002, São Paulo / SP
#
# 01-80 - INSCR. Est. Nº 112347 127 116
#
# conj
#
# - 151, 165º
#
#
#
# conj
#
#
#
#
#
# mg (
#
# M
#
# l
# l
#
# U
#
# en
# l
#
# U
#
# Y
#
# U
#
# Â
#
# 1
#
# ê
# É
#
# W
# m
#
# | e
#
# o
#
# ú
#
# (AA
#
# J
# 1
# j
# n
# o
# |
#
# l
# S
# o
#
# tempo
#
# ranta
#
#
#
# Qquando Tor fazes a SuUa Meserve em até 48
#
# operar no aeroporto de Guaruíhos (SRU), Congonhas
#
#
#
# FUSAS
#
#
#
#
#
#
#
#
#
# b
# é
# Ã
#
#
#
#
#
#
#
# d
# J
#
#
#
#
#
#
#
#
#
# ú
#
#
#
#
#
# 13
#
# ertre 05 al
#
# rido.
#
# o
#
# U
#
# Pauto, pod
# ente eles.
# 18
#
# 1
#
# conmn.
#
# 31 e 4
# 121 e 122, 13º
#
# conj
#
# 3
# n
# S
# =
# Ê
#
# Rua Vert
#
# 41 e 42, 5º
# . 131 e 132, 15º
#
# ial Nações Unidas. Chacara Santo Antonio, CEP |
#
# conj
#
# conj.
# o Espaço E
#
# i=
#
# &
# —
# M,
# EJ
# e
# &
#
# 1
#
# cio
#
#
#
# 10º
#
# m
#
#
#
# | e contém os detalhes do serviço
#
# . não é necessario leva-lo com você.
#
# te de
#
# CNPJ (M.F.) Nº 02012 862
# ado
#
# : Em
#
# s
# É&
# Ê
# &
# &
# &
# S
#
# "-
# m
#
# Z
#
#
#
# e a documentação
#
# | OTAVIO |
#
# o código
#
#
#
# ú
# a
#
# |
#
# 1
#
#
#
# e
#
#
#
#
#
#
#
#
#
# M
# b
#
#
#
#
#
# S
#
#
#
# e
#
#
#
# Y
#
#
#
# Ú
#
#
#
#
#
#
# n
#
# (
#
# |
#
#
#
# ú
#
#
#
# 1
#
#
#
#
#
# R
#
# fver alguma necessidade especial, Inf
#
# u
#
# !
# t feXDo D al eo
#
# —
#
# destino
# E levi-la com você e defina como
#
# ) E 0300 STD 5700 (iodo o
#
# eapiials)
# . com origem ou
# aeroporio vOCÊê será responsaável
#
#
#
# 2D
#
#
#
# Sh
#
# Lembre-se que 065 VOCG
# Conexao com troca de
#
# Confact Center
# es
#
# lgando para o
#
#
#
# i
# EEU VOO,
#
# CODOS
#
# W
#
# »”
#
# ereas
#
#
#
# M
#
#
#
#
#
# i
#
#
#
#
#
# Â
#
# local
#
#
#
# Ção
#
#
#
# q
#
#
#
# pago
# inerário
#
#
#
# (CGH]) ou
# » Quando sua
#
# n
#
#
#
#
#
#
#
# l
#
# |
#
# ú
# d
#
#
#
# E O Su
#
# No dia da
# Tenha
#
#
#
# etalhe companhias a
#
# Informação sobre sua passagem
#
#
#
# Toial
#
#
#
#
#
# Informa
# ./1613119/document-page4.jpg
# TAM Linhas Aéreas SJA
# Rua Verbo Divino Nº 2001, andares: 3º conj. 31 e 32,4* conj. 41 e 42, S"coms. 51 e 52, 6º conj. 01 e 62, 8º conj. B1 e &2,
#
#
#
#
#
# GNPJ (M.F.) Nº 02/0712.662/0001-60 - INSGR. Est. Nº 112.347.127.116
#
#
#
# te de compra e cmtamusde&hesdºmçuadqund&
#
# No dia da sua viagem, não é necessario leva-lo com você.
# Tenha em mãos apenas o código de reserva e a documentação de embarque
#
#
#
# mm a EA ,W,[
#
# E ; “ í m A «:»,"'!! "*:ª' É A A
# - ..*r«'*:,,*:tw,:,;“;;:ªªªª B É É , A AA "“"»h'*' o . R
# RRR y “ : 2 NA AA P
# .í:. A AA Âo m
#
# A T ,wª,, Ul i ;*t“ I('i“,“,'"'*.',.::«:e;,. '«rs'ç"º;“'
#
# TA
#
# AA
#
#
#
#
#
#
#
# x.h_ wm.'«/X/ux:lr*!õ'ª,v,g;ê:*«'“"l»"'ª"" A r.]í:?.«mw'sa'ív(l:ªª'í?fl:.i:i;ã:t;«(x_ A
# A .sgx'v,àã_.,,,whx* '““_4,',!,&»,,.
#
# ..,_»:z',.tc:,, A
# s d
#
# o
#
# «»'-'*'“u.mw« b n
#
# [ Tesernsa ) KCSYYE
# U u' .
#
# e bmmólimaç n am bmenio:
# m: *1«»% ENAA Xarª,.,ª:r::““ )
#
#
#
#
#
# EEA WÃ,', " .»..5,,»«;« EBEA SA : EA
# N | o : & m v A T
#
#
#
#
#
# AAA
#
#
#
#
#
# Uescnçaú do pagamenm Fomm de | amemm
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# a TT NNE —— " E
# o e d A l n .,l ' u Ú ,,._x:...:';lá...-m.. E
# e a lm ú in
#
#
#
# N
#
#
#
# J
#
#
#
#
#
#
#
#
#
#
#
#
#
# E r x U '..;_'.':—:,,:'yl,»*fl':!r:à',.ív'à* o .õ—.—.—«ªº'—“—'í' á p a s 1 h ENE UAA á : e mç (MA SS ASE , ,.,,J“.'.“,'?ª..,
# an D A AA 1 A A AAA AAA W A a a A Qin e ;;;.r,..,.., o | ú .u Y º*'““ª*"';ª"'ªª*'*'íª'ªª;-;ª"'íi'ªª “«W“*!W'º-'r'rª
#
#
#
# A ú A | 1 Ú .. " sm limand S [ ee la
# -;.«s:».'m«m;;w! jn ú *.,'. 3'( d a Ji a A E
#
# E
#
# T m o RRA
#
# vx,_...,....,,º.'.lt;m á
#
# ,4..,_,,.>;;;,,.,,.., o
#
# N A ,u-v,a,«u
# ='z.<'w n e m m E m.x,,
#
# ” .,,,..,,,,,_,..«;,. o ':rfa:ª:,—'r A M A 1 A o a a a D A
#
# y, ._,._.,_,4,,, .«mº*'“""' À «*“»;;;:,»::"', A S m *- S ÁA «*:r;v:»,(«,.»_,..:r,-:vyz(:::«;«x._—u u,)!« »,.w..,.W ;*—'-*«'v«'v«'va'« o NNA Vu ,W.,,,_=«======«w="'-;—'vr,y.w.u“,u
# e *:—,,;_« e o SNNA Ú M A A N ANT «v-fw'..,..w;.,.,.»x. la l *. e aaal f ª“l”r',«'“"“"—'«x"-“ é “'vw V M U A A N d LA ,wrv«w-«wv-'r' o
# m Â A Í A oA AN 1 mem e N j Vl A ES DAA E o
#
# d ú vrss«y.«..«;..—,—;., L
# n A
# W::z'v:'.«:;«,:, ( U A o d S A AA
# EA e
#
# »rv*:ºººa'y». S P A |
#
# J
#
# o a ,.,'_».,,..X LA
#
#
#
#
#
# » Iformação importante: Se você ou algum ites Iver alguma necessidade especial, Informe-nos: quando for fazer 2 6ua reserva em até 48 horas
# mmwmmmommmmwyemmmmam
# - Iformação mportante: Lembre-se que 065 voce dentro do Brasl!, com ongem ou destino em São Pauto, podem operar no aeroporto de Guarnuíhos (GRU), Conqonhas
# MMWMMMMWWWWM angporte entre eles. Confime a distância, garamta que você terá tempo
# Suficierte para pegar sua bagagem despacthiada e teva-ta mmeMmMMoWMmmmmm
#
#
#
# Detalhe companhms aereas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# l RAA MENA EA A AA " E AN E a
# 1 A e | h L e E N A U M NN
# A RL A *"*'*!zv:r:ªª*:“;m s“:àrªw?«z?--«'« ""— iE ,..'.«»«i»:::vv:a:ª;,:,_— U a aaa A n D
# ,««m.».,_«n«.r:«'ê&?é:fv' f WA 'Íflli];.)í',?“'ª ( e l «xvf«íã:l—ãi,";;k?ª dn w«xª'—'—':a»:%&“;&ªf» o o aa A [ É | l
# o o n;;;;:sá,gnx4,(.<; S e A o «vn:;«»r»fr'«»uz' a A A A A A .«,:"í"“ªf“mê«,'l*':%."«'n'i“'ú"l'*“ã'ªªf“x]íí
#
#
#
#
#
#
#
# nformação local
#
# 16
# ./1613120/ismael.jpg
# AIRLINES
#
#
#
# cnsine D 098 tmam º g S3 6 %S E7 Aem, Aº 4 A eem 354 BE S aues S 6 52 A dem V
#
# Tene tán a S So en SPA 07 4m que 2M S VS Avisen, STA MP ql SE Cidem 2íTe 2S
#
# 4 4i Usn 1 guaio À mee Jió Uniêm. S Rosana Sards Astugnts 521 12M 1006A Sde Vum -
# CNOr: MEA UE SÇO) PARRERSTAR foER 1R NJE ME Z
#
#
#
#
#
#
#
#
# Informação sobre sua passagem
# 4485 6 6 05 comercvação de compr e craée cm driiiem d emtsiio segurão.
# N dd cn ee maa Merm maaA
# ESA s Mil lsbree
#
#
#
#
#
#
#
#
#
# eeA
# a
# tma »
# —
# A A
#
#
#
# Upeenas  mcieeiaão ME A o am & maa
# TlA CATNIAS UISERRERA UEM o R me S am e
#
#
#
# « t e Sn Rs ta am nço pe gn a var naguãos f spm aa , cm s s Mi pue cu0t mo ta
# TERAN Ter tg me Vguge Mm L MS SmalOS « ón Min mEB DT S fugat a ds eomlricõe m OMRO, 2l
#
# Detalte : omponhiar aneoas
#
#
#
# Intormação cal
# ./1613128/document-page0.jpg
# NE
#
# Nº 000,000.580
#
# DUTOS/SERVIÇOS CONSTANTES DA NOTA PISCAL INDICADA-AO LADO
#
#
#
# e Tios DE STAR COMERCIAL E SERVICOS LTDA + EFPP OS PRO
#
#
#
#
#
#
#
#
#
# | IDENTIFICAÇÃO E ASSINATURA DO RECEBEDOR P
# SERIE:1
#
#
#
#
#
#
#
# S o o am oc ú cabo aa ÉS S S a o S a a o a S A s A o o aa sa a c o a a o s N a N o e A e cn o o é ó SN i c o o a o c c d a aa c á c s la s c c c
#
# inio A aa NOTao |
#
# STAR COMERCIAL E SERVICOS bn teicaree) mmN
#
# l i 7 o
#
#
#
#
#
#
#
#
#
#
# O = Entrada
# 1 - Saida
#
# ALAMEDA GRAJAU, 129 - SALA 804 - ALPHAVILLE CENTRO | Nº 000.000.580
# INDUSTRIAL E EMPRESARIAL/ALPHAVI, Barueri, SP - CEP: | coRIp:
#
# Página 1 de 1
#
#
#
#
# 3518 0328 8785 3100 0185 5800 1000 0008 8019 0300 0005
# Consulta de autenticidade no portal nacional da
# NF-e www.nfe.fazenda.gov.br/portal ou no site
# da Sefaz Autorizadora
# [rROTOCOLO DE AUTORIZAÇÃO DE USO
# 135180191736568 - 21/03/2018 13:09
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ NATUREZA DA OPERAÇÃO -
# 6102
# INSCRICAG ESTADUAL
# |2064723791 12
# DESTINATÁRIO/REMETENTE
# NOMERAZAG SÓCIAL
# Associação casa da cultura de Canaã dos Cara , 27.687.614/0001-40
# | ENDEREÇO BAIRRO/DISTEITO
#
# RUA DAS ESMERALDAS 141 - CASA DA | JARDIM DAS PALMEIRAS
#
# MUNICIPIO | . FONE/FAX :
# Canaa dos Carajas __
#
# FATURA — ,
# PAGAMENTO À VISTA
#
# CALCULO DO IMPOSTO
# BASE DE CALCULO DO IUMS
# -0,00
#
# VALOR DG SEGURO
#
#
#
#
#
#
#
#
#
#
#
#
#
# INSCRIÇÃO ESTADUAL DO SUBST TRIR.
#
# 28.578.531/0001-85
#
#
#
#
#
#
#
#
#
# DATA DA EMISSÃO
# 21/03/2018
# | DATA DE ENTRADA/SAIDA
# 121/03/2018
# HORA DE ENTRADASAIDA
#
# 1 13:05
#
# | CNPYCPE
#
#
#
#
#
#
#
# ás- ACC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Í VALOR TO1AL DOS PRODUTOS
# 1,427, 50
#
# VALOR TOTAL DA NOTA
#
#
#
# | BASE DE CALCULO DO ICMS ST | VALOR DO JOMS ST
#
#
#
#
#
# VALUA DO UMA
#
#
#
#
#
# —0,00
#
# É OUTRAS DESPESAS ACESSÓRIAS
#
#
#
#
#
#
#
#
#
#
# | VALOR DO FRETE É vaLoR DO (M
#
#
#
# 95,05 | 0,00
#
# TRANSPORTADOR/VOLUMES TRANSPORTADOS
# | RAZAOSOCIAL
#
# 1.451,17
#
#
#
#
#
#
# FRETE POR CONTA
# |- Destinatário/Remetente
#
#
#
#
#
#
#
#
# ENDERUEÇO
#
#
#
#
# COUANTIDADE
#
# DADOS DO PRODUTO/SERVIÇO
#
#
#
# a | Câmera Nikon COOLPIX BS00 Preta l | “eS2S8020 ww w:w um 1427,5000] — 1.427,50
#
#
#
# CÁLCULO DO ISSON
#
# INSCRIÇÃO MUNICIPAL * | VALOR TOTAL DOS SERVIÇOS BASE D CALCULO DO ISSON ] vALOR DO15SON
#
#
#
# DADOS ADICIONAIS
# INFORMAÇÕES COMPLEMENTARES
#
#
#
#
#
# fano Anual de Atividades de Casa da Guimura de
# dwa
# Camaâ dos Carajás 2017 . PRÓNAC 164246
# Lei Federa! de Incentivo à Cuiltura
#
# Róbrica E
#
#
#
# Intormações Adloiónais de Interesse doe Fiscos Hrindbes: Vart
# ao e Memnória S2ob (Cilásse 10) / Bolss Tripe e Klt limpera
# ./1613128/document-page1.jpg
# ---------------------------------------------------------------------------
# TesseractError                            Traceback (most recent call last)
# <ipython-input-48-50c96f821420> in <module>()
#      20         im = im.convert('1')
#      21         im.save(file)
# ---> 22         text = pytesseract.image_to_string(Image.open(file), lang='por')
#      23
#      24         os.remove(file)
#
# /usr/local/lib/python3.6/site-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, boxes, output_type)
#     284         return run_and_get_output(image, 'txt', lang, config, nice, True)
#     285
# --> 286     return run_and_get_output(image, 'txt', lang, config, nice)
#     287
#     288
#
# /usr/local/lib/python3.6/site-packages/pytesseract/pytesseract.py in run_and_get_output(image, extension, lang, config, nice, return_bytes)
#     192         }
#     193         try:
# --> 194             run_tesseract(**kwargs)
#     195             filename = kwargs['output_filename_base'] + os.extsep + extension
#     196             with open(filename, 'rb') as output_file:
#
# /usr/local/lib/python3.6/site-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice)
#     168
#     169     if status_code:
# --> 170         raise TesseractError(status_code, get_errors(error_string))
#     171
#     172     return True
#
# TesseractError: (-6, 'Tesseract Open Source OCR Engine v4.0.0-beta.2-313-g29f28 with Leptonica Warning. Invalid resolution 0 dpi. Using 70 instead. Estimating resolution as 532 contains_unichar_id(unichar_id):Error:Assert failed:in file ../../src/ccutil/unicharset.h, line 511')

# %% [markdown]
# ### 2. Extrair CNPJ a partir do texto

# %%
import re
import argparse
import cv2
import pytesseract
import os
import glob
from PIL import Image, ImageEnhance, ImageFilter

p = re.compile('\d{2}\.\d{3}\.\d{3}\/\d{4}-\d{2}')
foldernames = sorted(glob.glob('./*/'))
print(len(foldernames))
i = 0
for f in foldernames:
    foldersearch= f + "*.txt"
    filenames = sorted(glob.glob(foldersearch)) 
    for file in filenames:
        text_file = open( file , "r")
        for line in text_file:
            s = p.match(line)
            if s:
                print(s.group(), i)
                i += 1
# Out:
# 100
# 13.631.755/0001-36 0
# 13.631.755/0001-36 1
# 13.631.755/0001-36 2
# 09.272.200/0001-78 3
# 18.659.166/0001-80 4
# 09.272.200/0001-78 5
# 18.659.166/0001-80 6
# 09.272.200/0001-78 7
# 18.659.166/0001-80 8
# 09.272.200/0001-78 9
# 18.659.166/0001-80 10
# 18.659.166/0001-80 11
# 07.850.254/0001-48 12
# 09.272.200/0001-78 13
# 18.659.166/0001-80 14
# 18.659.166/0001-80 15
# 07.850.254/0001-48 16
# 18.659.166/0001-80 17
# 07.850.254/0001-48 18
# 07.850.254/0001-48 19
# 18.659.166/0001-80 20
# 09.272.200/0001-78 21
# 18.659.166/0001-80 22
# 28.398.653/0001-90 23
# 28.398.653/0001-90 24
# 22.762.192/0001-06 25
# 00.703.068/0001-37 26
# 00.000.644/4358-28 27

# %% [markdown]
# ### 3. Extrair Valor empenhado a partir do texto

# %% [markdown]
# ## Resultados e Analise

# %% [markdown]
# Para um primeiro experimento, conseguimos extrair de forma automatizada somente 30% dos CNPJs dos comprovantes, o que faz com que nao tenhamos atingido nossa meta de sucesso. Logo, há necessidade de evoluir principalmente o algoritmo de processamento de imagem para melhorar a qualidade dos comprovantes

# %% [markdown]
# ## Próximos passos

# %% [markdown]
# * [] Validar padrões regex nos arquivos pdf
# * [] extrair preços, a partir de regex
# * [] melhorar o processamento de imagem (filtros, contraste, orientação do scanner)
# * [] testar algoritmos de extraçao de texto a partir de arquivos pdf nativos (&& apt-get -y install poppler-utils )
